# %%
import os
import sys
import json
import pandas as pd
import numpy as np
import glob
from scipy.stats import ttest_ind
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

# %%
TOP_PATH = os.environ['PWD']
os.chdir(TOP_PATH + '/Desktop/Fair-Policing-Capstone/src')

# %%
from hypothesistesting import *

# %% [markdown]
# # T-Tests for All Races Pre- and Post- Event

# %%
print('T-Tests for All Races Pre- and Post- Event:')
print('-------------------------------------------------------------------------------------------------')
print('\n')
print('Asian:')

craTtest = get_ttest(allyears, 'Asian', 'Crazy_Rich_Asians_cleaned.csv', '2018-06-15', '2018-10-15')[0]
northTtest = get_ttest(allyears, 'Asian', 'North_Korea_war_cleaned.csv', '2017-02-01', '2017-06-01')[0]
print('Crazy Rich Asians: ' + str(craTtest))
print('North Korea War: ' + str(northTtest))
print('\n')

print('Black/African American:')
rayrice_tTest = get_ttest(allyears, 'Black/African American', 'Ray_Rice_cleaned.csv', '2014-07-08', '2014-11-08')[0]
bp_tTest = get_ttest(allyears, 'Black/African American', 'Black_Panther_cleaned.csv', '2017-12-16', '2018-04-16')[0]
print('Race Rice: ' + str(rayrice_tTest))
print('Black Panther: ' + str(bp_tTest))
print('\n')

print('Hispanic/Latino/a:')
dacaTtest = get_ttest(allyears, 'Hispanic/Latino/a', 'DACA_cleaned.csv', '2017-07-05', '2017-11-05')[0]
cocoTtest = get_ttest(allyears, 'Hispanic/Latino/a', 'Coco_cleaned.csv', '2017-09-22', '2018-01-22')[0]
print('DACA: ' + str(dacaTtest))
print('Coco: ' + str(cocoTtest))
print('\n')

print('White:')
leo_tTest = get_ttest(allyears, 'White', 'Leonardo_DiCaprio_cleaned.csv', '2015-12-28', '2016-04-28')[0]
uniteTtest = get_ttest(allyears, 'White', 'Unite_the_Right_cleaned.csv', '2017-06-12', '2017-10-12')[0]
print("Leonardo DiCaprio Oscar's Speech: " + str(leo_tTest))
print('Unite the Right Rally: ' + str(uniteTtest))
print('\n')
# Out:
# T-Tests for All Races Pre- and Post- Event:
# -------------------------------------------------------------------------------------------------
#
#
# Asian:
# Crazy Rich Asians: Ttest_indResult(statistic=1.6019156728497668, pvalue=0.11207980603737572)
# North Korea War: Ttest_indResult(statistic=-0.5945483308277218, pvalue=0.5533545168810203)
#
#
# Black/African American:
# Race Rice: Ttest_indResult(statistic=1.4239525179948356, pvalue=0.15701620910391373)
# Black Panther: Ttest_indResult(statistic=0.9954458438457331, pvalue=0.32351124262316944)
#
#
# Hispanic/Latino/a:
# DACA: Ttest_indResult(statistic=0.9733499438760127, pvalue=0.3323314915665416)
# Coco: Ttest_indResult(statistic=-0.9758159817135598, pvalue=0.3330081700033084)
#
#
# White:
# Leonardo DiCaprio Oscar's Speech: Ttest_indResult(statistic=0.5988775101931479, pvalue=0.5503779508409834)
# Unite the Right Rally: Ttest_indResult(statistic=0.24075417606527266, pvalue=0.8101535906648455)

# %% [markdown]
# # T-Tests for All Races Previous and Post-Year Event:

# %%
print('T-Tests for All Races Previous and/or Post-Year Event:')
print('-------------------------------------------------------------------------------------------------')
print('\n')

print('Asian:')
print('--------------------------')
print('Crazy Rich Asians (2018):')
craTtestpre = comparison(allyears, 'Asian', '2018-08-15', '2018-10-15', '2017-08-15', '2017-10-15')
northTtestpre = comparison(allyears, 'Asian', '2017-04-01', '2017-06-01', '2016-04-01', '2016-06-01')
northTtestpost = comparison(allyears, 'Asian', '2017-04-01', '2017-06-01', '2018-04-01', '2018-06-01')
print('2017 vs 2018: ' + str(craTtestpre))
print('\n')
print('North Korea War (2017):')
print('2016 vs 2017: ' + str(northTtestpre))
print('2017 vs 2018: ' + str(northTtestpost))
print('\n')

print('Black/African American:')
print('--------------------------')
print('Race Rice (2014):')
rayrice_tTest2 = comparison(allyears, 'Black/African American', '2014-09-08', '2014-11-08', '2015-09-08', '2015-11-08')
bp_tTest2 = comparison(allyears, 'Black/African American', '2018-02-16', '2018-04-16', '2017-02-16', '2017-04-16')
print('2014 vs 2015: ' + str(rayrice_tTest2))
print('\n')
print('Black Panther (2018):')
print('2017 vs 2018 ' + str(bp_tTest2))
print('\n')

print('Hispanic/Latino/a:')
print('--------------------------')
print('DACA (2017):')

dacaTtest2 = comparison(allyears, 'Hispanic/Latino/a', '2017-09-05', '2017-11-05', '2016-09-05', '2016-11-05')
dacaTtest3 = comparison(allyears, 'Hispanic/Latino/a', '2017-09-05', '2017-11-05', '2018-09-05', '2018-11-05')
cocoTtest2 = comparison(allyears, 'Hispanic/Latino/a', '2017-11-22', '2018-01-22', '2016-11-22', '2017-01-22')
print('2016 vs 2017: ' + str(dacaTtest2))
print('2017 vs 2018: ' + str(dacaTtest3))
print('\n')
print('Coco (2017/2018):')
print('2016/2017 vs 2017/2018: ' + str(cocoTtest2))
print('\n')

print('White:')
print('--------------------------')
print("Leonardo DiCaprio Oscar's Speech (2016):")


leo_tTest2 = comparison(allyears, 'White', '2016-02-28', '2016-04-28', '2015-02-28', '2015-04-28')
leo_tTest3 = comparison(allyears, 'White', '2016-02-28', '2016-04-28', '2017-02-28', '2017-04-28')
uniteTtest2 = comparison(allyears, 'White', '2017-08-12', '2017-10-12', '2016-08-12', '2016-10-12')
uniteTtest3 = comparison(allyears, 'White', '2017-08-12', '2017-10-12', '2018-08-12', '2018-10-12')
print("2015 vs 2016: " + str(leo_tTest2))
print("2016 vs 2017: " + str(leo_tTest3))
print('\n')
print('Unite the Right Rally (2017):')
print('2016 vs 2017: ' + str(uniteTtest2))
print('2017 vs 2018: ' + str(uniteTtest3))
# Out:
# T-Tests for All Races Previous and/or Post-Year Event:
# -------------------------------------------------------------------------------------------------
#
#
# Asian:
# --------------------------
# Crazy Rich Asians (2018):
# 2017 vs 2018: Ttest_indResult(statistic=-9.162592030202491, pvalue=4.7946014931186235e-15)
#
#
# North Korea War (2017):
# 2016 vs 2017: Ttest_indResult(statistic=-1.1556130020828737, pvalue=0.25009908170161954)
# 2017 vs 2018: Ttest_indResult(statistic=-2.914873985589936, pvalue=0.004423023852023051)
#
#
# Black/African American:
# --------------------------
# Race Rice (2014):
# 2014 vs 2015: Ttest_indResult(statistic=-2.5822543738438406, pvalue=0.011016851585581407)
#
#
# Black Panther (2018):
# 2017 vs 2018 Ttest_indResult(statistic=1.9576912178520067, pvalue=0.052775072025538994)
#
#
# Hispanic/Latino/a:
# --------------------------
# DACA (2017):
# 2016 vs 2017: Ttest_indResult(statistic=-1.967231926569222, pvalue=0.051452372508638586)
# 2017 vs 2018: Ttest_indResult(statistic=2.809010322695305, pvalue=0.005836114832484582)
#
#
# Coco (2017/2018):
# 2016/2017 vs 2017/2018: Ttest_indResult(statistic=0.9114047629343779, pvalue=0.3656679877434048)
#
#
# White:
# --------------------------
# Leonardo DiCaprio Oscar's Speech (2016):
# 2015 vs 2016: Ttest_indResult(statistic=-1.2684037151626044, pvalue=0.20720978207596702)
# 2016 vs 2017: Ttest_indResult(statistic=0.7320077188665005, pvalue=0.4656313322573191)
#
#
# Unite the Right Rally (2017):
# 2016 vs 2017: Ttest_indResult(statistic=-1.0718982603411968, pvalue=0.28588178983965007)
# 2017 vs 2018: Ttest_indResult(statistic=-5.91813009390678, pvalue=3.685778126708827e-08)

# %% [markdown]
# # Comparisons Pre-/Post- Year of Event For All Races

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Crazy Rich Asians 2017 vs 2018-----------')
for i in races:
    cra = comparison(allyears, i, '2018-08-15', '2018-10-15', '2017-08-15', '2017-10-15')
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Crazy Rich Asians 2017 vs 2018-----------
# {Asian}
#     statistic: -9.162592030202491
#     p-value: 4.7946014931186235e-15
# {Black/African American}
#     statistic: 12.413462341861957
#     p-value: 2.3338820791748716e-23
# {Hispanic/Latino/a}
#     statistic: -3.3829188771761745
#     p-value: 0.0009830713279062393
# {White}
#     statistic: 5.998211317616756
#     p-value: 2.6046584237059403e-08

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------North Korea War 2016 vs 2017-----------')
for i in races:
    cra = comparison(allyears, i, '2017-04-01', '2017-06-01', '2016-04-01', '2016-06-01')
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------North Korea War 2016 vs 2017-----------
# {Asian}
#     statistic: -1.1556130020828737
#     p-value: 0.25009908170161954
# {Black/African American}
#     statistic: 2.464818540869707
#     p-value: 0.015140502681160312
# {Hispanic/Latino/a}
#     statistic: -2.191676765627912
#     p-value: 0.030603327831381796
# {White}
#     statistic: 0.30233337959752676
#     p-value: 0.7629260558556001

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------North Korea War 2017 vs 2018-----------')
for i in races:
    cra = comparison(allyears, i, '2017-04-01', '2017-06-01', '2018-04-01', '2018-06-01')
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------North Korea War 2017 vs 2018-----------
# {Asian}
#     statistic: -2.914873985589936
#     p-value: 0.004423023852023051
# {Black/African American}
#     statistic: -0.7587366384128911
#     p-value: 0.44948110714368483
# {Hispanic/Latino/a}
#     statistic: 1.6218024252163512
#     p-value: 0.10743523005500302
# {White}
#     statistic: 1.3364099549228874
#     p-value: 0.183902858038706

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Ray Rice 2014 vs 2015-----------')
for i in races:
    cra = comparison(allyears, i, '2014-09-08', '2014-11-08', '2015-09-08', '2015-11-08')
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Ray Rice 2014 vs 2015-----------
# {Asian}
#     statistic: 2.418129117279785
#     p-value: 0.017088609771219686
# {Black/African American}
#     statistic: -2.5822543738438406
#     p-value: 0.011016851585581407
# {Hispanic/Latino/a}
#     statistic: -1.2436320953212718
#     p-value: 0.21610942422049856
# {White}
#     statistic: 2.7139867040500705
#     p-value: 0.007631260620118857

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Black Panther 2017 vs 2018-----------')
for i in races:
    cra = comparison(allyears, i, '2018-02-16', '2018-04-16', '2017-02-16', '2017-04-16')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Black Panther 2017 vs 2018-----------
# {Asian}
#     statistic: 4.689080930516635
#     p-value: 1.0173869889577994e-05
# {Black/African American}
#     statistic: 1.9576912178520067
#     p-value: 0.052775072025538994
# {Hispanic/Latino/a}
#     statistic: -0.31062975129402975
#     p-value: 0.7566393394262629
# {White}
#     statistic: -4.106967109142355
#     p-value: 7.59189243173755e-05

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------DACA 2016 vs 2017-----------')
for i in races:
    cra = comparison(allyears, i, '2017-09-05', '2017-11-05', '2016-09-05', '2016-11-05')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------DACA 2016 vs 2017-----------
# {Asian}
#     statistic: 3.4835593763788313
#     p-value: 0.0006940447249399635
# {Black/African American}
#     statistic: 1.928560996874801
#     p-value: 0.05616792781245604
# {Hispanic/Latino/a}
#     statistic: -1.967231926569222
#     p-value: 0.051452372508638586
# {White}
#     statistic: -2.43727031903354
#     p-value: 0.016258573015639075

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------DACA 2017 vs 2018-----------')
for i in races:
    cra = comparison(allyears, i, '2017-09-05', '2017-11-05', '2018-09-05', '2018-11-05')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------DACA 2017 vs 2018-----------
# {Asian}
#     statistic: 10.539334642594255
#     p-value: 1.3555755669027055e-17
# {Black/African American}
#     statistic: -11.992545329112714
#     p-value: 3.0584199248815923e-22
# {Hispanic/Latino/a}
#     statistic: 2.809010322695305
#     p-value: 0.005836114832484582
# {White}
#     statistic: -6.277634399875788
#     p-value: 9.178393353252999e-09

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Coco 2016/2017 vs 2017/2018-----------')
for i in races:
    cra = comparison(allyears, i, '2017-11-22', '2018-01-22', '2016-11-22', '2017-01-22')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Coco 2016/2017 vs 2017/2018-----------
# {Asian}
#     statistic: 1.070252528050468
#     p-value: 0.28872139569230215
# {Black/African American}
#     statistic: 1.0388232370194972
#     p-value: 0.30298508831095433
# {Hispanic/Latino/a}
#     statistic: 0.9114047629343779
#     p-value: 0.3656679877434048
# {White}
#     statistic: 0.2393033383585285
#     p-value: 0.8113843599816593

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Leonardo Dicaprio 2015 vs 2016-----------')
for i in races:
    cra = comparison(allyears, i, '2016-02-28', '2016-04-28', '2015-02-28', '2015-04-28')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Leonardo Dicaprio 2015 vs 2016-----------
# {Asian}
#     statistic: -1.414094911739046
#     p-value: 0.16004203319932186
# {Black/African American}
#     statistic: 0.32342879386789447
#     p-value: 0.7469425569131583
# {Hispanic/Latino/a}
#     statistic: 0.8888573953193106
#     p-value: 0.37590620245429895
# {White}
#     statistic: -1.2684037151626044
#     p-value: 0.20720978207596702

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Leonardo Dicaprio 2016 vs 2017-----------')
for i in races:
    cra = comparison(allyears, i, '2016-02-28', '2016-04-28', '2017-02-28', '2017-04-28')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Leonardo Dicaprio 2016 vs 2017-----------
# {Asian}
#     statistic: 3.1370929262523357
#     p-value: 0.0021595816168212857
# {Black/African American}
#     statistic: -1.8081860585386698
#     p-value: 0.07310569228375038
# {Hispanic/Latino/a}
#     statistic: 0.06339586363761002
#     p-value: 0.9495637490873918
# {White}
#     statistic: 0.7320077188665005
#     p-value: 0.4656313322573191

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Unite the Right Rally 2016 vs 2017-----------')
for i in races:
    cra = comparison(allyears, i, '2017-08-12', '2017-10-12', '2016-08-12', '2016-10-12')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Unite the Right Rally 2016 vs 2017-----------
# {Asian}
#     statistic: 1.737872097813585
#     p-value: 0.08490465867052426
# {Black/African American}
#     statistic: 1.374475920462421
#     p-value: 0.1719007191548513
# {Hispanic/Latino/a}
#     statistic: -1.2558910444523996
#     p-value: 0.21165228872478983
# {White}
#     statistic: -1.0718982603411968
#     p-value: 0.28588178983965007

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Unite the Right Rally 2017 vs 2018-----------')
for i in races:
    cra = comparison(allyears, i, '2017-08-12', '2017-10-12', '2018-08-12', '2018-10-12')
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Unite the Right Rally 2017 vs 2018-----------
# {Asian}
#     statistic: 9.025393507559794
#     p-value: 1.116506462352498e-14
# {Black/African American}
#     statistic: -12.59612634435069
#     p-value: 8.566619018174756e-24
# {Hispanic/Latino/a}
#     statistic: 3.250157505618401
#     p-value: 0.0015163151127847707
# {White}
#     statistic: -5.91813009390678
#     p-value: 3.685778126708827e-08

# %% [markdown]
# # T-Test Comparisons Per Event For All Races

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Crazy Rich Asians-----------')
for i in races:
    cra = get_ttest(allyears, i, 'Crazy_Rich_Asians_cleaned.csv', '2018-06-15', '2018-10-15')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Crazy Rich Asians-----------
# {Asian}
#     statistic: 1.6019156728497668
#     p-value: 0.11207980603737572
# {Black/African American}
#     statistic: -1.8285439711386773
#     p-value: 0.07005618393126134
# {Hispanic/Latino/a}
#     statistic: -1.4989769359649716
#     p-value: 0.1366277040093726
# {White}
#     statistic: 0.3097363498792934
#     p-value: 0.7573723220060193

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------North Korea War-----------')
for i in races:
    cra = get_ttest(allyears, i, 'North_Korea_war_cleaned.csv', '2017-02-01', '2017-06-01')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------North Korea War-----------
# {Asian}
#     statistic: -0.5945483308277218
#     p-value: 0.5533545168810203
# {Black/African American}
#     statistic: -1.490796425886857
#     p-value: 0.1386803120743011
# {Hispanic/Latino/a}
#     statistic: 1.3953861379120336
#     p-value: 0.16552435490343465
# {White}
#     statistic: 0.4903508107285896
#     p-value: 0.6248063698980495

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Ray Rice-----------')
for i in races:
    cra = get_ttest(allyears, i, 'Ray_Rice_cleaned.csv', '2014-07-08', '2014-11-08')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Ray Rice-----------
# {Asian}
#     statistic: -2.982537769887287
#     p-value: 0.0035074800013633577
# {Black/African American}
#     statistic: 1.4239525179948356
#     p-value: 0.15701620910391373
# {Hispanic/Latino/a}
#     statistic: 0.7803217599544854
#     p-value: 0.436719683840853
# {White}
#     statistic: 0.262520511839039
#     p-value: 0.7933724201275258

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Black Panther-----------')
for i in races:
    cra = get_ttest(allyears, i, 'Black_Panther_cleaned.csv', '2017-12-16', '2018-04-16')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Black Panther-----------
# {Asian}
#     statistic: 1.0136809587740307
#     p-value: 0.3148027925210791
# {Black/African American}
#     statistic: 0.9954458438457331
#     p-value: 0.32351124262316944
# {Hispanic/Latino/a}
#     statistic: 0.9807815107445795
#     p-value: 0.33062392143068975
# {White}
#     statistic: 1.9821365509565088
#     p-value: 0.05024297490386027

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------DACA-----------')
for i in races:
    cra = get_ttest(allyears, i, 'DACA_cleaned.csv', '2017-07-05', '2017-11-05')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------DACA-----------
# {Asian}
#     statistic: -3.536754237930671
#     p-value: 0.0005836858351044579
# {Black/African American}
#     statistic: -2.208765628463278
#     p-value: 0.029157082320254445
# {Hispanic/Latino/a}
#     statistic: 0.9733499438760127
#     p-value: 0.3323314915665416
# {White}
#     statistic: 2.3870481213339554
#     p-value: 0.0186028526586431

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print('----------Coco-----------')
for i in races:
    cra = get_ttest(allyears, i, 'Coco_cleaned.csv', '2017-09-22', '2018-01-22')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Coco-----------
# {Asian}
#     statistic: -1.0130256464184213
#     p-value: 0.3150484329813606
# {Black/African American}
#     statistic: -1.0354867628606073
#     p-value: 0.30452756523626007
# {Hispanic/Latino/a}
#     statistic: -0.9758159817135598
#     p-value: 0.3330081700033084
# {White}
#     statistic: -0.9575139715354095
#     p-value: 0.3404575467753793

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print("----------Leonardo DiCaprio's Oscars Speech-----------")
for i in races:
    cra = get_ttest(allyears, i, 'Leonardo_DiCaprio_cleaned.csv', '2015-12-28', '2016-04-28')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Leonardo DiCaprio's Oscars Speech-----------
# {Asian}
#     statistic: -0.7494519398002171
#     p-value: 0.4550869913853651
# {Black/African American}
#     statistic: 0.9443342203704115
#     p-value: 0.3468811496159322
# {Hispanic/Latino/a}
#     statistic: -0.5928317515507169
#     p-value: 0.5544004645613307
# {White}
#     statistic: 0.5988775101931479
#     p-value: 0.5503779508409834

# %%
races = ['Asian', 'Black/African American', 'Hispanic/Latino/a', 'White']
lst = []
print("----------Unite the Right Rally-----------")
for i in races:
    cra = get_ttest(allyears, i, 'Unite_the_Right_cleaned.csv', '2017-06-12', '2017-10-12')[0]
    lst.append(cra)
    print('{' + i + '}')
    print('    statistic: ' +str(cra.statistic))
    print('    p-value: ' + str(cra.pvalue))
# Out:
# ----------Unite the Right Rally-----------
# {Asian}
#     statistic: -2.265165804817765
#     p-value: 0.025540220047430777
# {Black/African American}
#     statistic: -0.40233109168222436
#     p-value: 0.6881507286800443
# {Hispanic/Latino/a}
#     statistic: 0.3436419238948872
#     p-value: 0.7317171437964751
# {White}
#     statistic: 0.24075417606527266
#     p-value: 0.8101535906648455

# %% [markdown]
# # Graphs

# %%
cra = get_ttest(allyears, 'Asian', 'Crazy_Rich_Asians.csv', '2018-06-15', '2018-10-15')[1]
cra['Google_Searches'] = cra.value
cra2 = cra.set_index('date')
three = pd.DataFrame(cra2.Stop_Counts.rolling(3).mean())
copy1 = cra.copy()
copy1 = copy1[['date', 'Google_Searches']]
nt2 = copy1.merge(three, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For Crazy Rich Asians Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %%
daca = get_ttest(allyears, 'Hispanic/Latino/a', 'DACA.csv', '2017-07-05', '2017-11-05')[1]
daca['Google_Searches'] = daca.value
da2 = daca.set_index('date')
t = pd.DataFrame(da2.Stop_Counts.rolling(3).mean())
copy = daca.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For DACA Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/hudaahmed/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
leo = get_ttest(allyears, 'White', 'Leonardo_DiCaprio.csv', '2015-12-28', '2016-04-28')[1]
leo['Google_Searches'] = leo.value
leo2 = leo.set_index('date')
t = pd.DataFrame(leo2.Stop_Counts.rolling(3).mean())
copy = leo.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For Leonardo DiCaprio Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
ticklabels = [item.strftime('%Y-%m-%d') for item in nt2.date][::14]
plt.gca().xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=14))
plt.gcf().autofmt_xdate()

# %%
rayrice = get_ttest(allyears, 'Black/African American', 'Ray_Rice.csv', '2014-07-08', '2014-11-08')[1]
rayrice['Google_Searches'] = rayrice.value
rayrice2 = rayrice.set_index('date')
t = pd.DataFrame(rayrice2.Stop_Counts.rolling(3).mean())
copy = rayrice.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For Ray Rice Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
ticklabels = [item.strftime('%Y-%m-%d') for item in nt2.date][::14]
plt.gca().xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=14))
plt.gcf().autofmt_xdate()

# %%
bp = get_ttest(allyears, 'Black/African American', 'Black_Panther.csv', '2017-12-16', '2018-04-16')[1]
bp['Google_Searches'] = bp.value
bp2 = bp.set_index('date')
t = pd.DataFrame(bp2.Stop_Counts.rolling(3).mean())
copy = bp.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For Black Panther Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %%
coco = get_ttest(allyears, 'Hispanic/Latino/a', 'Coco.csv', '2017-09-22', '2018-01-22')[1]
coco['Google_Searches'] = coco.value
coco2 = coco.set_index('date')
t = pd.DataFrame(coco2.Stop_Counts.rolling(3).mean())
copy = coco.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For Coco Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %%
unite = get_ttest(allyears, 'White', 'Unite_the_Right.csv', '2017-06-12', '2017-10-12')[1]
unite['Google_Searches'] = unite.value
un2 = unite.set_index('date')
t = pd.DataFrame(un2.Stop_Counts.rolling(3).mean())
copy = unite.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
nt2.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For Unite the Right Rally Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
ticklabels = [item.strftime('%Y-%m-%d') for item in nt2.date][::14]
plt.gca().xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=14))
plt.gcf().autofmt_xdate()

# %%
north = get_ttest(allyears, 'White', 'North_Korea_war.csv', '2017-02-01', '2017-06-01')[1]
north['Google_Searches'] = north.value
n2 = north.set_index('date')
t = pd.DataFrame(n2.Stop_Counts.rolling(3).mean())
copy = north.copy()
copy = copy[['date', 'Google_Searches']]
nt2 = copy.merge(t, on = 'date')
north.plot(x="date", y=["Stop_Counts", "Google_Searches"])
plt.title('Stop Counts vs Google Trend Searches For North Korea War Threats Over 4 Months')
plt.xlabel('Date')
plt.ylabel('Counts')
ticklabels = [item.strftime('%Y-%m-%d') for item in nt2.date][::14]
plt.gca().xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=14))
plt.gcf().autofmt_xdate()

# %%
data = allyears

# %%
os.chdir(TOP_PATH + '/Desktop/Fair-Policing-Capstone/upload_data')

# %%
df = pd.read_csv('com.csv')
df = df[2:].reset_index(drop = True)
df = df.rename(columns={"Category: All categories": "date_stop", "Unnamed: 1": "daca", "Unnamed: 2": "coco"})

# %%
df
# Out:
#       date_stop daca coco
# 0    2015-05-10    1    6
# 1    2015-05-17    1    6
# 2    2015-05-24    1    6
# 3    2015-05-31   <1    6
# 4    2015-06-07   <1    6
# ..          ...  ...  ...
# 255  2020-03-29    1    6
# 256  2020-04-05    1    7
# 257  2020-04-12    1    7
# 258  2020-04-19    1    7
# 259  2020-04-26    1    7
#
# [260 rows x 3 columns]

# %%
df['date_stop'] = pd.to_datetime(df.date_stop, format= '%Y-%m-%d')
df.daca = pd.to_numeric(df.daca, errors='coerce')
#df.daca[np.isnan(df.daca)] = 0
df.coco = pd.to_numeric(df.coco, errors='coerce')
#df.coco[np.isnan(df.coco)] = 0
graph = pd.DataFrame()
graph['columns'] = df.isna().sum().index
graph['values'] = df.isna().sum().values
graph = graph.set_index('columns')
graph.plot(kind = 'bar')
plt.title('Non-Numeric Values in Interest Across Events Graphs')
plt.xlabel('Columns')
plt.ylabel('Counts')
# Out:
# Text(0,0.5,'Counts')

# %%
data['date_stop'] = pd.to_datetime(data.date_stop, format= '%Y-%m-%d')

# %%
#nw = df.merge(data, on = 'date_stop')

# %%
val = data.groupby('date_stop')['stop_id'].count().values
ind = data.groupby('date_stop')['stop_id'].count().index
newdf1 = pd.DataFrame()
newdf1['date_stop'] = ind
newdf1['Stop_Counts'] = val
nw = df.merge(newdf1, on = 'date_stop')
nw
# Out:
#      date_stop  daca  coco  Stop_Counts
# 0   2015-05-10   1.0     6          156
# 1   2015-05-17   1.0     6          129
# 2   2015-05-24   1.0     6          260
# 3   2015-05-31   0.0     6          222
# 4   2015-06-07   0.0     6          515
# ..         ...   ...   ...          ...
# 229 2019-12-01   1.0     7          390
# 230 2019-12-08   1.0     7          305
# 231 2019-12-15   1.0     7          384
# 232 2019-12-22   1.0     7          386
# 233 2019-12-29   1.0     7          331
#
# [234 rows x 4 columns]

# %%
nw.plot(x="date_stop", y=["daca", "coco"])
plt.title('Interest Across Events for Hispanic Drivers')
plt.xlabel('Date')
plt.ylabel('Google Trends Interest')
ticklabels = [item.strftime('%Y-%m-%d') for item in nw.date_stop][::14]
plt.gca().xaxis.set_major_formatter(ticker.FixedFormatter(ticklabels))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=150))
plt.gcf().autofmt_xdate()
